# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunkay7/AIML-IIITH/blob/main/AIML_Project_Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project for Module 4: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  x**3 - x**2

def dg(x):
    return 3*x**2 - 2*x

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function for g(x)
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(-3, 3)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3)

# 2 Chart: Derivative of g(x)
plt.subplot(1, 2, 2)

plt.title('Derivative of g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 6)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.6418253013032678
# Number of steps: 54

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1,
                                                 multiplier=0.001, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.207607911494572
# Number of steps: 301

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1,
                                                 multiplier=0.001, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.207607911494572
# Number of steps: 301

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples
x_3 = np.linspace(-5, 5, 1000)
def h(x):
  return x**5 - 2*x**4 + 2
def dh(x):
  return 5*x**4 - 8*x**3 + 2

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function for g(x)
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(-3, 3)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.plot(x_3, h(x_3), color='blue', linewidth=3)

# 2 Chart: Derivative of g(x)
plt.subplot(1, 2, 2)

plt.title('Derivative of h(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 6)

plt.plot(x_3, dh(x_3), color='skyblue', linewidth=5)

plt.show()

# %%
local_min, list_x, deriv_list = gradient_descent(dh, initial_guess=0.1, multiplier=0.001, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.6094050512559144
# Number of steps: 301

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(dh, initial_guess=0.1, multiplier=0.001, precision=0.0001)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.plot(x_3, h(x_3), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_3, dh(x_3), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  73

# %%
## TASK-5 : Run gradient descent 3 times
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.001, precision=0.0001, max_iter=n)

high_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                              multiplier=0.002, precision=0.0001, max_iter=n)

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting mid_gamma and high_gamma learning rates
plt.figure(figsize=[15, 5])

# Mid_gamma
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Mid Gamma (0.001)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

mid_gamma_values = np.array(mid_gamma[1])
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(mid_gamma_values, g(mid_gamma_values), color='red', s=100, alpha=0.6)

# High_gamma
plt.subplot(1, 2, 2)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('High Gamma (0.002)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

high_gamma_values = np.array(high_gamma[1])
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(high_gamma_values, g(high_gamma_values), color='red', s=100, alpha=0.6)

plt.show()

# %%
## TASK-7 : Plot reduction in cost for each iteration

# Function to calculate the cost at each iteration
def calculate_cost(x_values, cost_func):
    return [cost_func(x) for x in x_values]

# Calling gradient descent function for mid_gamma
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.001, precision=0.0001, max_iter=n)

# Calculating cost for each iteration
cost_values_mid_gamma = calculate_cost(mid_gamma[1], g)

# Plotting the reduction in cost for mid_gamma
plt.figure(figsize=[10, 5])

plt.title('Reduction in Cost for Mid Gamma (0.001)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)

plt.plot(range(len(cost_values_mid_gamma)), cost_values_mid_gamma, color='green', marker='o', linestyle='-')

plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples
import numpy as np
import matplotlib.pyplot as plt

# Given function and its derivatives
def z(x, y):
    r = 3 - x**2 - y**2
    return 1 / (r + 1)

def dz_dx(x, y):
    r = 3 - x**2 - y**2
    dr_dx = 2 * x
    return -2 * x / (r + 1)**2

def dz_dy(x, y):
    r = 3 - x**2 - y**2
    dr_dy = 2 * y
    return -2 * y / (r + 1)**2

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, z(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', z(a, b))
print('Partial derivative wrt x is: ', diff(z(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      z(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(z(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function f(x, y) is:  1/(-x**2 - y**2 + 4)
# Partial derivative wrt x is:  2*y/(-x**2 - y**2 + 4)**2
# Value of f(x,y) at x=1.8 y=1.0 is:  -4.16666666666666
# Value of partial derivative wrt x:  62.4999999999999

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(z(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(z(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', z(params[0], params[1]))
# Out:
# Values in gradient array [0.0774079397932183 0.0430044109962325]
# Minimum occurs at x value of:  0.508314391458292
# Minimum occurs at y value of:  0.282396884143496
# The cost is:  0.273084630336428

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    r = 3 - x**2 - y**2
    dr_dx = 2 * x
    return -2 * x / (r + 1)**2

def fpy(x, y):
    r = 3 - x**2 - y**2
    dr_dy = 2 * y
    return -2 * y / (r + 1)**2

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', z(params[0], params[1]))
# Out:
# Values in gradient array [-0.00235207 -0.00130671]
# Minimum occurs at x value of:  8.17015479443108
# Minimum occurs at y value of:  4.5389748857950565
# The cost is:  -0.011997064695623205

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', z(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [-0.00241909 -0.00134394]
# Minimum occurs at x value of:  8.098601781645009
# Minimum occurs at y value of:  4.499223212025013
# The cost is:  -0.012220403233909312

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, z(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           z(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    mse_calc = 1/7 * sum((y - y_hat)**2)
    mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
import numpy as np

# Provided values
theta0 = 0.847535148603
theta1 = 1.22272646378
x_5 = np.array([1, 2, 3, 4, 5, 6, 7])
y_5 = np.array([1.2, 1.9, 3.2, 4.1, 5.0, 5.8, 7.1])

# Calculating y_hat
y_hat = theta0 + theta1 * x_5

# Calculating Mean Squared Error (MSE)
def mse(y, y_hat):
    return np.mean((y - y_hat)**2)

# Calling mse function
mse_value = mse(y_5, y_hat)

# Printing the results
print('Estimated values (y_hat) are:\n', y_hat)
print('Actual y values are:\n', y_5)
print('Mean Squared Error (MSE) is:', mse_value)
# Out:
# Estimated values (y_hat) are:
#  [2.07026161 3.29298808 4.51571454 5.738441   6.96116747 8.18389393
#  9.4066204 ]
# Actual y values are:
#  [1.2 1.9 3.2 4.1 5.  5.8 7.1]
# Mean Squared Error (MSE) is: 3.137570069391235

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: 3.137570069391235
# MSE regression using manual calc is 3.137570069391235
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-e57d70940b2a> in <cell line: 3>()
#       1 print('Manually calculated MSE is:', mse(y_5, y_hat))
#       2 print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
# ----> 3 print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900             # If input is 1D raise error
#     901             if array.ndim == 1:
# --> 902                 raise ValueError(
#     903                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1 2 3 4 5 6 7].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5175879396984926
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.5376884422110555
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.557788944723618
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.577889447236181
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.5979899497487438
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6180904522613067
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.6381909547738696
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.658291457286432
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.678391959798995
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.698492462311558
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7185929648241207
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.7386934673366836
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# 2.758793969849246
# ...
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.899497487437186
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.919597989949749
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9396984924623117
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.9597989949748746
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 2.979899497487437
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# 3.0
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.017203569895421107
# Min occurs at (i,j): (98, 58)
# Min MSE for Theta 0 at plot_t0[111][91] 0.16582914572864316
# Min MSE for Theta 1 at plot_t1[111][91] 0.9698492462311559

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
import numpy as np

def grad(x, y, thetas):
    n = y.size

    theta0_slope = (-2/n) * np.sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * np.sum((y - thetas[0] - thetas[1]*x) * x)

    return np.array([theta0_slope, theta1_slope])

# Example usage:
x_values = np.array([1, 2, 3, 4, 5, 6, 7])
y_values = np.array([1.2, 1.9, 3.2, 4.1, 5.0, 5.8, 7.1])
theta_parameters = np.array([0.5, 0.5])  # Example initial values

# Calling grad function
gradient = grad(x_values, y_values, theta_parameters)

# Printing the gradient
print('Gradient:', gradient)
# Out:
# Gradient: [ -3.08571429 -16.14285714]

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.19117848625377204
# Min occurs at Theta 1: 0.9652419388194664
# MSE is: 0.01755900312089053

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()

# %% [markdown]
# ## Notes
#
#
#
# 1. **Derivative Calculation:**
#    - We started by defining a linear regression model \(y = \theta_0 + \theta_1 x\).
#    - To optimize the model, we aimed to minimize the Mean Squared Error (MSE), a measure of the model's accuracy.
#    - Calculating the derivatives of the MSE with respect to the model parameters (\(\theta_0\) and \(\theta_1\)) is crucial for gradient descent.
#
# 2. **Partial Derivatives:**
#    - We derived partial derivatives of the MSE with respect to both \(\theta_0\) and \(\theta_1\).
#    - The partial derivatives represent the slopes of the cost function concerning each parameter and guide the optimization process.
#
# 3. **Gradient Descent:**
#    - The partial derivatives were used to form the gradient vector, indicating the direction and magnitude of steepest ascent in the cost function space.
#    - Gradient descent is an iterative optimization algorithm that updates model parameters in the opposite direction of the gradient to minimize the cost.
#
# 4. **Implementation:**
#    - We implemented a function (`grad`) to calculate the gradient, incorporating the partial derivatives.
#    - This function is used within the gradient descent algorithm to iteratively update model parameters and minimize the cost.
#
#
#
# 1. **MSE Calculation:**
#    - We calculated the predicted values (\(y_{\text{hat}}\)) using a linear regression model with given parameters (\(\theta_0\) and \(\theta_1\)).
#    - A Mean Squared Error (MSE) function was defined to measure the accuracy of the model by comparing the predicted values with the actual values.
#
# 2. **Gradient Calculation:**
#    - We implemented a gradient descent function (`grad`) to calculate the gradient of the cost function with respect to the model parameters (\(\theta_0\) and \(\theta_1\)).
#    - The gradient provides the direction and magnitude for updating the parameters during the optimization process.
